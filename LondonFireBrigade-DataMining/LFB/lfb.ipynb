# %%
import pandas as pd

# %%
# filepath = "/content/drive/MyDrive/Colab Notebooks/LFB/LFB_2019-22.xlsx"
# df = pd.read_excel(filepath)

# %%
pd.options.display.max_columns = None
# df.head(2)
# Out:
#     IncidentNumber   DateOfCall  CalYear TimeOfCall  HourOfCall  \
# 0  000006-01012019  01 Jan 2019     2019   00:01:45           0
# 1  000019-01012019  01 Jan 2019     2019   00:04:33           0
#
#      IncidentGroup StopCodeDescription SpecialServiceType PropertyCategory  \
# 0  Special Service     Special Service       Lift Release         Dwelling
# 1             Fire      Secondary Fire                NaN          Outdoor
#
#                                         PropertyType  \
# 0  Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 1                                        Tree scrub
#
#                    AddressQualifier Postcode_full Postcode_district  \
# 0         Correct incident location           NaN              SE11
# 1  On land associated with building        N9 7HU                N9
#
#         UPRN      USRN IncGeo_BoroughCode IncGeo_BoroughName ProperCase  \
# 0          0  21901674          E09000022            LAMBETH    Lambeth
# ...

# %%
# df1 = df.loc[df['IncGeo_BoroughName'] == 'LAMBETH']
# df1.head(2)
# Out:
#     IncidentNumber   DateOfCall  CalYear TimeOfCall  HourOfCall  \
# 0  000006-01012019  01 Jan 2019     2019   00:01:45           0
# 7  000060-01012019  01 Jan 2019     2019   00:11:22           0
#
#      IncidentGroup StopCodeDescription SpecialServiceType PropertyCategory  \
# 0  Special Service     Special Service       Lift Release         Dwelling
# 7             Fire      Secondary Fire                NaN          Outdoor
#
#                                         PropertyType  \
# 0  Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 7                                      Loose refuse
#
#                         AddressQualifier Postcode_full Postcode_district  \
# 0              Correct incident location           NaN              SE11
# 7  In street close to gazetteer location       SW2 4JR               SW2
#
#            UPRN      USRN IncGeo_BoroughCode IncGeo_BoroughName ProperCase  \
# 0             0  21901674          E09000022            LAMBETH    Lambeth
# ...

# %%
# df1.shape
# Out:
# (17868, 39)

# %%
# df1.to_csv("/content/drive/MyDrive/Colab Notebooks/LFB/lambeth.csv")

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LFB/lambeth.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0   IncidentNumber   DateOfCall  CalYear TimeOfCall  HourOfCall  \
# 0           0  000006-01012019  01 Jan 2019     2019   00:01:45           0
# 1           7  000060-01012019  01 Jan 2019     2019   00:11:22           0
#
#      IncidentGroup StopCodeDescription SpecialServiceType PropertyCategory  \
# 0  Special Service     Special Service       Lift Release         Dwelling
# 1             Fire      Secondary Fire                NaN          Outdoor
#
#                                         PropertyType  \
# 0  Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 1                                      Loose refuse
#
#                         AddressQualifier Postcode_full Postcode_district  \
# 0              Correct incident location           NaN              SE11
# 1  In street close to gazetteer location       SW2 4JR               SW2
#
#            UPRN      USRN IncGeo_BoroughCode IncGeo_BoroughName ProperCase  \
# ...
